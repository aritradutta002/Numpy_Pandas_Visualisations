# %%
import numpy as np
import pandas as pd

# %%
data1 = pd.read_csv('train.csv')
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data2 = pd.read_csv('test.csv')
data2
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
#Write a code to concatenate data1 & data2 assign it as data_01

# %%
data_01 = pd.concat((df,df1),sort=False,join='inner')
data_01
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 413         1305       3                                 Spector, Mr. Woolf
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
# 415         1307       3                       Saether, Mr. Simon Sivertsen
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
# Write a code to show the average fare for all individual 'Pclass' for data_01

# %%
data_01.groupby(by='Pclass').mean()['Fare']
# Out:
# Pclass
# 1    87.508992
# 2    21.179196
# 3    13.302889
# Name: Fare, dtype: float64

# %%
data_01.groupby(by='Embarked').mean()['Pclass']
# Out:
# Embarked
# C    1.851852
# Q    2.894309
# S    2.347921
# Name: Pclass, dtype: float64

# %%
# write a code to show the median of age and mean for Fare on the basis of sex

# %%
data_01.groupby(by='Sex').agg({'Age':'median','Fare':'mean'})
# Out:
#          Age       Fare
# Sex
# female  27.0  46.198097
# male    28.0  26.154601

# %%
## Write a code to show the average age of all the genders as per there respective passenger class(Pclass) for data_01.

# %%
pd.pivot_table(data_01,index='Pclass',columns='Sex',aggfunc='mean',values='Age')
# Out:
# Sex        female       male
# Pclass
# 1       37.037594  41.029272
# 2       27.499223  30.815380
# 3       22.185329  25.962264

# %%
#Write a code to show the median age of all the genders and average Fare as per there respective passenger class(Pclass) for data_01.

# %%
pd.pivot_table(data_01,index='Pclass',columns='Sex',aggfunc={'Age':'median','Fare':'mean'},values=['Age','Fare'])
# Out:
#           Age              Fare
# Sex    female  male      female       male
# Pclass
# 1        36.0  42.0  109.412385  69.888385
# 2        28.0  29.5   23.234827  19.904946
# 3        22.0  25.0   15.324250  12.415462

# %%
data_01['Last_Name'] = data_01['Name'].apply(lambda x : str(x).split(', ')[0])
data_01['First_Name'] = data_01['Name'].apply(lambda x : str(x).split(', ')[1])
data_01[['Last_Name','First_Name']]
# Out:
#          Last_Name                                  First_Name
# 0           Braund                             Mr. Owen Harris
# 1          Cumings  Mrs. John Bradley (Florence Briggs Thayer)
# 2        Heikkinen                                 Miss. Laina
# 3         Futrelle          Mrs. Jacques Heath (Lily May Peel)
# 4            Allen                           Mr. William Henry
# ..             ...                                         ...
# 413        Spector                                   Mr. Woolf
# 414  Oliva y Ocana                               Dona. Fermina
# 415        Saether                         Mr. Simon Sivertsen
# 416           Ware                               Mr. Frederick
# 417          Peter                           Master. Michael J
#
# [1309 rows x 2 columns]

# %%
data_01.insert(3,column='First',value=data_01['First_Name'])
data_01
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 413         1305       3                                 Spector, Mr. Woolf
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
# 415         1307       3                       Saether, Mr. Simon Sivertsen
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
data_02 = data_01.rename(mapper={'Sex':'Gender'},axis=1)
data_01
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 413         1305       3                                 Spector, Mr. Woolf
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
# 415         1307       3                       Saether, Mr. Simon Sivertsen
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...
