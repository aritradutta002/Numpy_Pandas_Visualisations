# %%
import pandas as pd

# %%
df = pd.read_csv('Automobile.csv')

# %% [markdown]
# 1. symboling: -3, -2, -1, 0, 1, 2, 3.
# 2. normalized-losses: continuous from 65 to 256.
# 3. make:
# alfa-romero, audi, bmw, chevrolet, dodge, honda,
# isuzu, jaguar, mazda, mercedes-benz, mercury,
# mitsubishi, nissan, peugot, plymouth, porsche,
# renault, saab, subaru, toyota, volkswagen, volvo
#
# 4. fuel-type: diesel, gas.
# 5. aspiration: std, turbo.
# 6. num-of-doors: four, two.
# 7. body-style: hardtop, wagon, sedan, hatchback, convertible.
# 8. drive-wheels: 4wd, fwd, rwd.
# 9. engine-location: front, rear.
# 10. wheel-base: continuous from 86.6 120.9.
# 11. length: continuous from 141.1 to 208.1.
# 12. width: continuous from 60.3 to 72.3.
# 13. height: continuous from 47.8 to 59.8.
# 14. curb-weight: continuous from 1488 to 4066.
# 15. engine-type: dohc, dohcv, l, ohc, ohcf, ohcv, rotor.
# 16. num-of-cylinders: eight, five, four, six, three, twelve, two.
# 17. engine-size: continuous from 61 to 326.
# 18. fuel-system: 1bbl, 2bbl, 4bbl, idi, mfi, mpfi, spdi, spfi.
# 19. bore: continuous from 2.54 to 3.94.
# 20. stroke: continuous from 2.07 to 4.17.
# 21. compression-ratio: continuous from 7 to 23.
# 22. horsepower: continuous from 48 to 288.
# 23. peak-rpm: continuous from 4150 to 6600.
# 24. city-mpg: continuous from 13 to 49.
# 25. highway-mpg: continuous from 16 to 54.
# 26. price: continuous from 5118 to 45400.

# %%
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
#1.Check the head of the DataFrame.

# %%
df.head(11)
# Out:
#     symboling  normalized_losses         make fuel_type aspiration  \
# 0           3                168  alfa-romero       gas        std
# 1           3                168  alfa-romero       gas        std
# 2           1                168  alfa-romero       gas        std
# 3           2                164         audi       gas        std
# 4           2                164         audi       gas        std
# 5           2                161         audi       gas        std
# 6           1                158         audi       gas        std
# 7           1                168         audi       gas        std
# 8           1                158         audi       gas      turbo
# 9           2                192          bmw       gas        std
# 10          0                192          bmw       gas        std
#
#    number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0              two  convertible          rwd           front        88.6  ...
# ...

# %%
#2. How many rows and columns are there.

# %%
df.shape
# Out:
# (201, 26)

# %%
print("number of rows",df.shape[0])
# Out:
# number of rows 201

# %%
print("number of columns",df.shape[1])
# Out:
# number of columns 26

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
# symboling              201 non-null int64
# normalized_losses      201 non-null int64
# make                   201 non-null object
# fuel_type              201 non-null object
# aspiration             201 non-null object
# number_of_doors        201 non-null object
# body_style             201 non-null object
# drive_wheels           201 non-null object
# engine_location        201 non-null object
# wheel_base             201 non-null float64
# length                 201 non-null float64
# width                  201 non-null float64
# height                 201 non-null float64
# curb_weight            201 non-null int64
# engine_type            201 non-null object
# number_of_cylinders    201 non-null object
# engine_size            201 non-null int64
# fuel_system            201 non-null object
# bore                   201 non-null float64
# ...

# %%
#3.What is the average Price of all cars in the dataset.

# %%
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
df['price'].mean()
# Out:
# 13207.129353233831

# %%
import numpy as np
np.average(df['price'])
# Out:
# 13207.129353233831

# %%
df.loc[:,'price'].mean()
# Out:
# 13207.129353233831

# %%
#4 Which is the cheapest make and costliest make of car in the lot.

# %%
df.head()    #price, make
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
df[df['price']==df.loc[:,'price'].max()].make
# Out:
# 71    mercedes-benz
# Name: make, dtype: object

# %%
df[df['price']==df.loc[:,'price'].min()].make
# Out:
# 134    subaru
# Name: make, dtype: object

# %%
df2=df[['price']]
df2.sort_values(by='price',axis=0,ascending=True)  
df.iloc[[134]][['make','price']]
# Out:
#        make  price
# 134  subaru   5118

# %%
df.sort_values(by='price',axis=0,ascending=True)['make'][134]
# Out:
# 'subaru'

# %%
df.sort_values(by='price',ascending = True)[['make','price']].head(1)
# Out:
#        make  price
# 134  subaru   5118

# %%
# 5.How many cars have horsepower greater than 100.

# %%
df[df['horsepower']>100].shape[0]
# Out:
# 90

# %%
df[df['horsepower']>100].count()['make']
# Out:
# 90

# %%
len(df[df['horsepower']>100])
# Out:
# 90

# %%
# 6.How many hatchback cars are in the dataset.

# %%
a=df.loc[(df['body_style']=='hatchback')]
a.shape[0]
# Out:
# 68

# %%
len(df[df['body_style']=='hatchback'])
# Out:
# 68

# %%
#7.Someone purchased a car for 7099, what is the make of the car?

# %%
df.loc[(df['price']==7099)]['make']
# Out:
# 87    nissan
# Name: make, dtype: object

# %%
#8. Which are the cars that are both a sedan and priced less than 7000?

# %%
df.loc[(df.loc[:,'body_style'] == 'sedan') & (df.loc[:,'price'] < 7000)]['make']
# Out:
# 19      chevrolet
# 24          dodge
# 42          isuzu
# 50          mazda
# 82     mitsubishi
# 86         nissan
# 88         nissan
# 89         nissan
# 118      plymouth
# 152        toyota
# Name: make, dtype: object

# %%
# 9.Show the prices of cars in ascending order.

# %%
df1 = df.sort_values('price')
df1
# Out:
#      symboling  normalized_losses           make fuel_type aspiration  \
# 134          2                 83         subaru       gas        std
# 17           2                121      chevrolet       gas        std
# 47           1                104          mazda       gas        std
# 146          1                 87         toyota       gas        std
# 73           2                161     mitsubishi       gas        std
# ..         ...                ...            ...       ...        ...
# 16           0                149            bmw       gas        std
# 125          3                128        porsche       gas        std
# 70           0                140  mercedes-benz       gas        std
# 15           0                149            bmw       gas        std
# 71           1                140  mercedes-benz       gas        std
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# ...

# %%
df1.sort_values(by='price',ascending=False)
# Out:
#      symboling  normalized_losses           make fuel_type aspiration  \
# 71           1                140  mercedes-benz       gas        std
# 15           0                149            bmw       gas        std
# 70           0                140  mercedes-benz       gas        std
# 125          3                128        porsche       gas        std
# 16           0                149            bmw       gas        std
# ..         ...                ...            ...       ...        ...
# 73           2                161     mitsubishi       gas        std
# 146          1                 87         toyota       gas        std
# 47           1                104          mazda       gas        std
# 17           2                121      chevrolet       gas        std
# 134          2                 83         subaru       gas        std
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# ...

# %%
#10. What is the rank order of the cars as per there horsepower.

# %%
df['rank_horsepower']= df['horsepower'].rank(method='min')

# %%
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df["hprank"] = df['horsepower'].rank(axis=0, method = 'min',ascending=False)

# %%
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...
