# %%
import numpy as np
import pandas as pd

# %%
dfleft = pd.read_csv('profit11.csv')
dfright = pd.read_csv('profit12.csv')

# %%
dfm = pd.merge(dfleft,dfright,left_on='Catg',right_on='Grp',how='outer',indicator=True)
dfm
# Out:
#     Vol_x  Rev_x  Exp Catg  EmpCnt_x HQ_x  Vol_y  Rev_y   Expn  Grp  EmpCnt_y  \
# 0     931    863  605  Pub      1935  Che  192.0  221.0  165.0  Pub    1154.0
# 1     931    863  605  Pub      1935  Che  131.0  263.0  105.0  Pub    1935.0
# 2     931    863  605  Pub      1935  Che  199.0  217.0  174.0  Pub    1443.0
# 3     992    821  665  Pub      1154  Che  192.0  221.0  165.0  Pub    1154.0
# 4     992    821  665  Pub      1154  Che  131.0  263.0  105.0  Pub    1935.0
# 5     992    821  665  Pub      1154  Che  199.0  217.0  174.0  Pub    1443.0
# 6     931    217  674  Pub      1443  Mum  192.0  221.0  165.0  Pub    1154.0
# 7     931    217  674  Pub      1443  Mum  131.0  263.0  105.0  Pub    1935.0
# 8     931    217  674  Pub      1443  Mum  199.0  217.0  174.0  Pub    1443.0
# 9     932    881  650  Gov      1361  Blr    NaN    NaN    NaN  NaN       NaN
# 10    925    839  615  Pvt       154  Mum  125.0  239.0  115.0  Pvt     154.0
#
#    HQ_y     _merge
# ...

# %%
dfleft
# Out:
#           Vol  Rev  Exp Catg  EmpCnt   HQ
# Infy      931  863  605  Pub    1935  Che
# MRF       992  821  665  Pub    1154  Che
# ISROACL   932  881  650  Gov    1361  Blr
# Reliance  931  217  674  Pub    1443  Mum
# BCCI      925  839  615  Pvt     154  Mum

# %%
dfright
# Out:
#          Vol  Rev  Expn  Grp  EmpCnt   HQ
# MRF      192  221   165  Pub    1154  Che
# Apollo   131  263   105  Pub    1935  Che
# Infosys  199  217   174  Pub    1443  Blr
# ISL      125  239   115  Pvt     154  NCR

# %%
dfm = pd.merge(dfleft,dfright,left_on='Catg',right_on='Grp',how='inner',indicator=True)
dfm
# Out:
#    Vol_x  Rev_x  Exp Catg  EmpCnt_x HQ_x  Vol_y  Rev_y  Expn  Grp  EmpCnt_y  \
# 0    931    863  605  Pub      1935  Che    192    221   165  Pub      1154
# 1    931    863  605  Pub      1935  Che    131    263   105  Pub      1935
# 2    931    863  605  Pub      1935  Che    199    217   174  Pub      1443
# 3    992    821  665  Pub      1154  Che    192    221   165  Pub      1154
# 4    992    821  665  Pub      1154  Che    131    263   105  Pub      1935
# 5    992    821  665  Pub      1154  Che    199    217   174  Pub      1443
# 6    931    217  674  Pub      1443  Mum    192    221   165  Pub      1154
# 7    931    217  674  Pub      1443  Mum    131    263   105  Pub      1935
# 8    931    217  674  Pub      1443  Mum    199    217   174  Pub      1443
# 9    925    839  615  Pvt       154  Mum    125    239   115  Pvt       154
#
#   HQ_y _merge
# 0  Che   both
# 1  Che   both
# 2  Blr   both
# 3  Che   both
# 4  Che   both
# 5  Blr   both
# 6  Che   both
# ...

# %%
dfm = pd.merge(dfleft,dfright,left_index=True,right_index=True,how='inner',indicator=True)
dfm
# Out:
#      Vol_x  Rev_x  Exp Catg  EmpCnt_x HQ_x  Vol_y  Rev_y  Expn  Grp  EmpCnt_y  \
# MRF    992    821  665  Pub      1154  Che    192    221   165  Pub      1154
#
#     HQ_y _merge
# MRF  Che   both

# %%
dfm = pd.merge(dfleft,dfright,left_index=True,right_index=True,how='outer',indicator=True)
dfm
# Out:
#           Vol_x  Rev_x    Exp Catg  EmpCnt_x HQ_x  Vol_y  Rev_y   Expn  Grp  \
# Apollo      NaN    NaN    NaN  NaN       NaN  NaN  131.0  263.0  105.0  Pub
# BCCI      925.0  839.0  615.0  Pvt     154.0  Mum    NaN    NaN    NaN  NaN
# ISL         NaN    NaN    NaN  NaN       NaN  NaN  125.0  239.0  115.0  Pvt
# ISROACL   932.0  881.0  650.0  Gov    1361.0  Blr    NaN    NaN    NaN  NaN
# Infosys     NaN    NaN    NaN  NaN       NaN  NaN  199.0  217.0  174.0  Pub
# Infy      931.0  863.0  605.0  Pub    1935.0  Che    NaN    NaN    NaN  NaN
# MRF       992.0  821.0  665.0  Pub    1154.0  Che  192.0  221.0  165.0  Pub
# Reliance  931.0  217.0  674.0  Pub    1443.0  Mum    NaN    NaN    NaN  NaN
#
#           EmpCnt_y HQ_y      _merge
# Apollo      1935.0  Che  right_only
# BCCI           NaN  NaN   left_only
# ISL          154.0  NCR  right_only
# ISROACL        NaN  NaN   left_only
# Infosys     1443.0  Blr  right_only
# Infy           NaN  NaN   left_only
# ...
