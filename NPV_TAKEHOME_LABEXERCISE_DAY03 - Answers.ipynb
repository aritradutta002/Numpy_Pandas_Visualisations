# %% [markdown]
# # TAKE HOME LAB EXERCISE

# %%
import pandas as pd

# %% [markdown]
# -----------------------

# %% [markdown]
# **Q.no (1) . Write a code to load 'employees.csv' as `df`.**

# %%
df = pd.read_csv('employees.csv')
df
# Out:
#     Id        F_Name           S_Name     Sex         DOB        Department  \
# 0    1         Brown              Mia    Male  11/24/1987     Admin Offices
# 1    2     LaRotonda         William     Male   4/26/1984     Admin Offices
# 2    3        Steans         Tyrone      Male  09-01-1986     Admin Offices
# 3    4        Howard          Estelle    Male   9/16/1985     Admin Offices
# 4    5         Singh             Nan     Male   5/19/1988     Admin Offices
# 5    6         Smith        Leigh Ann    Male   6/14/1987     Admin Offices
# 6    7       LeBlanc       Brandon  R    Male  06-10-1984     Admin Offices
# 7    8         Quinn             Sean  Female  11-06-1984     Admin Offices
# 8    9      Boutwell          Bonalyn  Female  04-04-1987     Admin Offices
# 9   10  Foster-Baker              Amy  Female   4/16/1979     Admin Offices
# 10  11          King            Janet  Female   9/21/1954  Executive Office
# 11  12        Zamora         Jennifer  Female   8/30/1979             IT/IS
# 12  13        Becker            Renee  Female  04-04-1986             IT/IS
# 13  14         Goble           Taisha  Female  10/23/1971             IT/IS
# 14  15     Hernandez           Daniff    Male  08-07-1986             IT/IS
# 15  16        Horton            Jayne    Male   2/21/1984             IT/IS
# 16  17       Johnson          Noelle     Male  11-07-1986             IT/IS
# 17  18        Murray           Thomas    Male  07-04-1988             IT/IS
# 18  19       Pearson          Randall    Male  09-05-1984             IT/IS
# 19  20     Petrowsky           Thelma    Male   9/16/1984             IT/IS
# 20  21          Roby            Lori     Male  10-11-1981             IT/IS
# 21  22        Rogers             Ivan    Male   8/26/1986             IT/IS
# 22  23        Salter            Jason  Female  12/17/1987             IT/IS
# 23  24        Simard           Kramer  Female  02-08-1970             IT/IS
# 24  25          Zhou            Julia  Female   2/24/1979             IT/IS
# 25  26          Foss            Jason  Female  07-05-1980             IT/IS
# 26  27          Roup            Simon  Female  04-05-1973             IT/IS
# 27  28          Ruiz          Ricardo  Female  01-04-1964             IT/IS
# 28  29        Monroe            Peter  Female  10-05-1986             IT/IS
# 29  30       Dougall             Eric  Female  07-09-1970             IT/IS
# 30  31       Clayton             Rick  Female  09-05-1985             IT/IS
# 31  32         Galia             Lisa  Female  07-06-1968             IT/IS
# 32  33       Lindsay         Leonara   Female  10-05-1988             IT/IS
# 33  34          Soto           Julia   Female  03-12-1973             IT/IS
# 34  35         Bacon       Alejandro   Female  01-07-1988             IT/IS
# 35  36         Cisco          Anthony  Female  11/24/1989             IT/IS
# 36  37         Dolan            Linda  Female   7/18/1988             IT/IS
# 37  38      Gonzalez            Maria  Female   4/16/1981             IT/IS
# 38  39        Merlos           Carlos    Male   6/18/1987             IT/IS
# 39  40        Morway            Tanya    Male  04-04-1979             IT/IS
# 40  41       Shepard           Anita     Male   4/14/1981             IT/IS
# 41  42    Tredinnick         Neville     Male  05-05-1988             IT/IS
# 42  43        Turpin            Jumil    Male   3/31/1969             IT/IS
# 43  44      Ait Sidi   Karthikeyan       Male  05-05-1975             IT/IS
# 44  45          Carr       Claudia  N    Male  06-06-1986             IT/IS
# 45  46         Favis         Donald    Female   7/30/1964             IT/IS
# 46  47      Roehrich           Bianca  Female   5/27/1973             IT/IS
# 47  48       Daniele             Ann   Female   1/18/1952             IT/IS
# 48  49       Lajiri             Jyoti    Male   4/23/1986             IT/IS
# 49  50    Semizoglou       Jeremiah      Male  02-09-1983             IT/IS
#
#                  Designation  Years_Exp   Location  Salary
# 0               Accountant I          7  Bangalore   10000
# 1               Accountant I          8  Bangalore   10000
# 2               Accountant I          7  Bangalore   10000
# 3   Administrative Assistant          4  Bangalore   15000
# 4   Administrative Assistant          9  Bangalore   15000
# 5   Administrative Assistant          3  Bangalore   15000
# 6    Shared Services Manager          2  Bangalore   20000
# 7    Shared Services Manager          4  Bangalore   20000
# 8             Sr. Accountant          5  Bangalore   20000
# 9             Sr. Accountant          3  Bangalore   20000
# 10           President & CEO          4  Bangalore  120000
# 11                       CIO          6  Bangalore  120000
# 12    Database Administrator          4  Bangalore   50000
# 13    Database Administrator          5  Bangalore   50000
# 14    Database Administrator          3  Bangalore   50000
# 15    Database Administrator          6  Bangalore   50000
# 16    Database Administrator          2  Bangalore   50000
# 17    Database Administrator          3  Bangalore   50000
# 18    Database Administrator          4  Bangalore   50000
# 19    Database Administrator          5  Bangalore   50000
# 20    Database Administrator          4  Bangalore   50000
# 21    Database Administrator          6  Bangalore   50000
# 22    Database Administrator          5  Bangalore   50000
# 23    Database Administrator          7  Bangalore   50000
# 24    Database Administrator          8  Bangalore   50000
# 25               IT Director          7  Bangalore   75000
# 26           IT Manager - DB          5  Bangalore   75000
# 27           IT Manager - DB          4  Bangalore   75000
# 28        IT Manager - Infra          5  Bangalore   75000
# 29      IT Manager - Support          5  Bangalore   75000
# 30                IT Support          5  Bangalore   80000
# 31                IT Support          5  Bangalore   80000
# 32                IT Support          5  Bangalore   80000
# 33                IT Support          9  Bangalore   80000
# 34          Network Engineer          8  Bangalore   85000
# 35          Network Engineer          6  Bangalore   85000
# 36          Network Engineer          5  Bangalore   85000
# 37          Network Engineer          6  Bangalore   85000
# 38          Network Engineer          4  Bangalore   85000
# 39          Network Engineer          4  Bangalore   85000
# 40          Network Engineer          5  Bangalore   85000
# 41          Network Engineer          6  Bangalore   85000
# 42          Network Engineer          6  Bangalore   85000
# 43                   Sr. DBA          3  Bangalore   95000
# 44                   Sr. DBA          6  Bangalore   95000
# 45                   Sr. DBA          7  Bangalore   95000
# 46                   Sr. DBA          5  Bangalore   95000
# 47      Sr. Network Engineer          6  Bangalore  100000
# 48      Sr. Network Engineer          4  Bangalore  100000
# 49      Sr. Network Engineer          4  Bangalore  100000

# %% [markdown]
# ----------------

# %% [markdown]
# **Q.no(2).Write a code to `MERGE`(`outer`)  df1 & df2 as `data`.**

# %%
df1 = pd.read_csv('train.csv')
df2 = pd.read_csv('test.csv')
data = pd.merge(df1,df2,how='outer')
data
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...                                                 ...     ...   ...    ...
# 1304                                 Spector, Mr. Woolf    male   NaN      0
# 1305                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 1307                                Ware, Mr. Frederick    male   NaN      0
# 1308                           Peter, Master. Michael J    male   NaN      1
#
#       Parch              Ticket      Fare Cabin Embarked
# 0         0           A/5 21171    7.2500   NaN        S
# 1         0            PC 17599   71.2833   C85        C
# 2         0    STON/O2. 3101282    7.9250   NaN        S
# 3         0              113803   53.1000  C123        S
# 4         0              373450    8.0500   NaN        S
# ...     ...                 ...       ...   ...      ...
# 1304      0           A.5. 3236    8.0500   NaN        S
# 1305      0            PC 17758  108.9000  C105        C
# 1306      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307      0              359309    8.0500   NaN        S
# 1308      1                2668   22.3583   NaN        C
#
# [1309 rows x 12 columns]

# %% [markdown]
# ----------------

# %% [markdown]
# **Q.no(3) . Write a code to `RENAME` the column from `salary` to `earnings`  of `employees dataset` and assign it to the new dataframe named as `data_01` .**

# %%
data_01 = df.rename(mapper={'Salary':'earnings'},axis=1)
data_01
# Out:
#     Id        F_Name           S_Name     Sex         DOB        Department  \
# 0    1         Brown              Mia    Male  11/24/1987     Admin Offices
# 1    2     LaRotonda         William     Male   4/26/1984     Admin Offices
# 2    3        Steans         Tyrone      Male  09-01-1986     Admin Offices
# 3    4        Howard          Estelle    Male   9/16/1985     Admin Offices
# 4    5         Singh             Nan     Male   5/19/1988     Admin Offices
# 5    6         Smith        Leigh Ann    Male   6/14/1987     Admin Offices
# 6    7       LeBlanc       Brandon  R    Male  06-10-1984     Admin Offices
# 7    8         Quinn             Sean  Female  11-06-1984     Admin Offices
# 8    9      Boutwell          Bonalyn  Female  04-04-1987     Admin Offices
# 9   10  Foster-Baker              Amy  Female   4/16/1979     Admin Offices
# 10  11          King            Janet  Female   9/21/1954  Executive Office
# 11  12        Zamora         Jennifer  Female   8/30/1979             IT/IS
# 12  13        Becker            Renee  Female  04-04-1986             IT/IS
# 13  14         Goble           Taisha  Female  10/23/1971             IT/IS
# 14  15     Hernandez           Daniff    Male  08-07-1986             IT/IS
# 15  16        Horton            Jayne    Male   2/21/1984             IT/IS
# 16  17       Johnson          Noelle     Male  11-07-1986             IT/IS
# 17  18        Murray           Thomas    Male  07-04-1988             IT/IS
# 18  19       Pearson          Randall    Male  09-05-1984             IT/IS
# 19  20     Petrowsky           Thelma    Male   9/16/1984             IT/IS
# 20  21          Roby            Lori     Male  10-11-1981             IT/IS
# 21  22        Rogers             Ivan    Male   8/26/1986             IT/IS
# 22  23        Salter            Jason  Female  12/17/1987             IT/IS
# 23  24        Simard           Kramer  Female  02-08-1970             IT/IS
# 24  25          Zhou            Julia  Female   2/24/1979             IT/IS
# 25  26          Foss            Jason  Female  07-05-1980             IT/IS
# 26  27          Roup            Simon  Female  04-05-1973             IT/IS
# 27  28          Ruiz          Ricardo  Female  01-04-1964             IT/IS
# 28  29        Monroe            Peter  Female  10-05-1986             IT/IS
# 29  30       Dougall             Eric  Female  07-09-1970             IT/IS
# 30  31       Clayton             Rick  Female  09-05-1985             IT/IS
# 31  32         Galia             Lisa  Female  07-06-1968             IT/IS
# 32  33       Lindsay         Leonara   Female  10-05-1988             IT/IS
# 33  34          Soto           Julia   Female  03-12-1973             IT/IS
# 34  35         Bacon       Alejandro   Female  01-07-1988             IT/IS
# 35  36         Cisco          Anthony  Female  11/24/1989             IT/IS
# 36  37         Dolan            Linda  Female   7/18/1988             IT/IS
# 37  38      Gonzalez            Maria  Female   4/16/1981             IT/IS
# 38  39        Merlos           Carlos    Male   6/18/1987             IT/IS
# 39  40        Morway            Tanya    Male  04-04-1979             IT/IS
# 40  41       Shepard           Anita     Male   4/14/1981             IT/IS
# 41  42    Tredinnick         Neville     Male  05-05-1988             IT/IS
# 42  43        Turpin            Jumil    Male   3/31/1969             IT/IS
# 43  44      Ait Sidi   Karthikeyan       Male  05-05-1975             IT/IS
# 44  45          Carr       Claudia  N    Male  06-06-1986             IT/IS
# 45  46         Favis         Donald    Female   7/30/1964             IT/IS
# 46  47      Roehrich           Bianca  Female   5/27/1973             IT/IS
# 47  48       Daniele             Ann   Female   1/18/1952             IT/IS
# 48  49       Lajiri             Jyoti    Male   4/23/1986             IT/IS
# 49  50    Semizoglou       Jeremiah      Male  02-09-1983             IT/IS
#
#                  Designation  Years_Exp   Location  earnings
# 0               Accountant I          7  Bangalore     10000
# 1               Accountant I          8  Bangalore     10000
# 2               Accountant I          7  Bangalore     10000
# 3   Administrative Assistant          4  Bangalore     15000
# 4   Administrative Assistant          9  Bangalore     15000
# 5   Administrative Assistant          3  Bangalore     15000
# 6    Shared Services Manager          2  Bangalore     20000
# 7    Shared Services Manager          4  Bangalore     20000
# 8             Sr. Accountant          5  Bangalore     20000
# 9             Sr. Accountant          3  Bangalore     20000
# 10           President & CEO          4  Bangalore    120000
# 11                       CIO          6  Bangalore    120000
# 12    Database Administrator          4  Bangalore     50000
# 13    Database Administrator          5  Bangalore     50000
# 14    Database Administrator          3  Bangalore     50000
# 15    Database Administrator          6  Bangalore     50000
# 16    Database Administrator          2  Bangalore     50000
# 17    Database Administrator          3  Bangalore     50000
# 18    Database Administrator          4  Bangalore     50000
# 19    Database Administrator          5  Bangalore     50000
# 20    Database Administrator          4  Bangalore     50000
# 21    Database Administrator          6  Bangalore     50000
# 22    Database Administrator          5  Bangalore     50000
# 23    Database Administrator          7  Bangalore     50000
# 24    Database Administrator          8  Bangalore     50000
# 25               IT Director          7  Bangalore     75000
# 26           IT Manager - DB          5  Bangalore     75000
# 27           IT Manager - DB          4  Bangalore     75000
# 28        IT Manager - Infra          5  Bangalore     75000
# 29      IT Manager - Support          5  Bangalore     75000
# 30                IT Support          5  Bangalore     80000
# 31                IT Support          5  Bangalore     80000
# 32                IT Support          5  Bangalore     80000
# 33                IT Support          9  Bangalore     80000
# 34          Network Engineer          8  Bangalore     85000
# 35          Network Engineer          6  Bangalore     85000
# 36          Network Engineer          5  Bangalore     85000
# 37          Network Engineer          6  Bangalore     85000
# 38          Network Engineer          4  Bangalore     85000
# 39          Network Engineer          4  Bangalore     85000
# 40          Network Engineer          5  Bangalore     85000
# 41          Network Engineer          6  Bangalore     85000
# 42          Network Engineer          6  Bangalore     85000
# 43                   Sr. DBA          3  Bangalore     95000
# 44                   Sr. DBA          6  Bangalore     95000
# 45                   Sr. DBA          7  Bangalore     95000
# 46                   Sr. DBA          5  Bangalore     95000
# 47      Sr. Network Engineer          6  Bangalore    100000
# 48      Sr. Network Engineer          4  Bangalore    100000
# 49      Sr. Network Engineer          4  Bangalore    100000

# %% [markdown]
# -----------------

# %% [markdown]
# **Q.no(4) . Write a code to `drop` the column 'DOB' of `employees dataset` and assign it to the new dataframe named as `data_02`.**

# %%
data_02 = df.drop(labels='DOB',axis=1)
data_02
# Out:
#     Id        F_Name           S_Name     Sex        Department  \
# 0    1         Brown              Mia    Male     Admin Offices
# 1    2     LaRotonda         William     Male     Admin Offices
# 2    3        Steans         Tyrone      Male     Admin Offices
# 3    4        Howard          Estelle    Male     Admin Offices
# 4    5         Singh             Nan     Male     Admin Offices
# 5    6         Smith        Leigh Ann    Male     Admin Offices
# 6    7       LeBlanc       Brandon  R    Male     Admin Offices
# 7    8         Quinn             Sean  Female     Admin Offices
# 8    9      Boutwell          Bonalyn  Female     Admin Offices
# 9   10  Foster-Baker              Amy  Female     Admin Offices
# 10  11          King            Janet  Female  Executive Office
# 11  12        Zamora         Jennifer  Female             IT/IS
# 12  13        Becker            Renee  Female             IT/IS
# 13  14         Goble           Taisha  Female             IT/IS
# 14  15     Hernandez           Daniff    Male             IT/IS
# 15  16        Horton            Jayne    Male             IT/IS
# 16  17       Johnson          Noelle     Male             IT/IS
# 17  18        Murray           Thomas    Male             IT/IS
# 18  19       Pearson          Randall    Male             IT/IS
# 19  20     Petrowsky           Thelma    Male             IT/IS
# 20  21          Roby            Lori     Male             IT/IS
# 21  22        Rogers             Ivan    Male             IT/IS
# 22  23        Salter            Jason  Female             IT/IS
# 23  24        Simard           Kramer  Female             IT/IS
# 24  25          Zhou            Julia  Female             IT/IS
# 25  26          Foss            Jason  Female             IT/IS
# 26  27          Roup            Simon  Female             IT/IS
# 27  28          Ruiz          Ricardo  Female             IT/IS
# 28  29        Monroe            Peter  Female             IT/IS
# 29  30       Dougall             Eric  Female             IT/IS
# 30  31       Clayton             Rick  Female             IT/IS
# 31  32         Galia             Lisa  Female             IT/IS
# 32  33       Lindsay         Leonara   Female             IT/IS
# 33  34          Soto           Julia   Female             IT/IS
# 34  35         Bacon       Alejandro   Female             IT/IS
# 35  36         Cisco          Anthony  Female             IT/IS
# 36  37         Dolan            Linda  Female             IT/IS
# 37  38      Gonzalez            Maria  Female             IT/IS
# 38  39        Merlos           Carlos    Male             IT/IS
# 39  40        Morway            Tanya    Male             IT/IS
# 40  41       Shepard           Anita     Male             IT/IS
# 41  42    Tredinnick         Neville     Male             IT/IS
# 42  43        Turpin            Jumil    Male             IT/IS
# 43  44      Ait Sidi   Karthikeyan       Male             IT/IS
# 44  45          Carr       Claudia  N    Male             IT/IS
# 45  46         Favis         Donald    Female             IT/IS
# 46  47      Roehrich           Bianca  Female             IT/IS
# 47  48       Daniele             Ann   Female             IT/IS
# 48  49       Lajiri             Jyoti    Male             IT/IS
# 49  50    Semizoglou       Jeremiah      Male             IT/IS
#
#                  Designation  Years_Exp   Location  Salary
# 0               Accountant I          7  Bangalore   10000
# 1               Accountant I          8  Bangalore   10000
# 2               Accountant I          7  Bangalore   10000
# 3   Administrative Assistant          4  Bangalore   15000
# 4   Administrative Assistant          9  Bangalore   15000
# 5   Administrative Assistant          3  Bangalore   15000
# 6    Shared Services Manager          2  Bangalore   20000
# 7    Shared Services Manager          4  Bangalore   20000
# 8             Sr. Accountant          5  Bangalore   20000
# 9             Sr. Accountant          3  Bangalore   20000
# 10           President & CEO          4  Bangalore  120000
# 11                       CIO          6  Bangalore  120000
# 12    Database Administrator          4  Bangalore   50000
# 13    Database Administrator          5  Bangalore   50000
# 14    Database Administrator          3  Bangalore   50000
# 15    Database Administrator          6  Bangalore   50000
# 16    Database Administrator          2  Bangalore   50000
# 17    Database Administrator          3  Bangalore   50000
# 18    Database Administrator          4  Bangalore   50000
# 19    Database Administrator          5  Bangalore   50000
# 20    Database Administrator          4  Bangalore   50000
# 21    Database Administrator          6  Bangalore   50000
# 22    Database Administrator          5  Bangalore   50000
# 23    Database Administrator          7  Bangalore   50000
# 24    Database Administrator          8  Bangalore   50000
# 25               IT Director          7  Bangalore   75000
# 26           IT Manager - DB          5  Bangalore   75000
# 27           IT Manager - DB          4  Bangalore   75000
# 28        IT Manager - Infra          5  Bangalore   75000
# 29      IT Manager - Support          5  Bangalore   75000
# 30                IT Support          5  Bangalore   80000
# 31                IT Support          5  Bangalore   80000
# 32                IT Support          5  Bangalore   80000
# 33                IT Support          9  Bangalore   80000
# 34          Network Engineer          8  Bangalore   85000
# 35          Network Engineer          6  Bangalore   85000
# 36          Network Engineer          5  Bangalore   85000
# 37          Network Engineer          6  Bangalore   85000
# 38          Network Engineer          4  Bangalore   85000
# 39          Network Engineer          4  Bangalore   85000
# 40          Network Engineer          5  Bangalore   85000
# 41          Network Engineer          6  Bangalore   85000
# 42          Network Engineer          6  Bangalore   85000
# 43                   Sr. DBA          3  Bangalore   95000
# 44                   Sr. DBA          6  Bangalore   95000
# 45                   Sr. DBA          7  Bangalore   95000
# 46                   Sr. DBA          5  Bangalore   95000
# 47      Sr. Network Engineer          6  Bangalore  100000
# 48      Sr. Network Engineer          4  Bangalore  100000
# 49      Sr. Network Engineer          4  Bangalore  100000

# %% [markdown]
# -----------------

# %% [markdown]
# **Q.no(5) . Write a code to `drop` the `column no. 3 ` of `data_02` as per there `index position` .**

# %%
data_02.drop(data_02.columns[2],inplace=True,axis=1)
data_02
# Out:
#     Id        F_Name     Sex        Department               Designation  \
# 0    1         Brown    Male     Admin Offices              Accountant I
# 1    2     LaRotonda    Male     Admin Offices              Accountant I
# 2    3        Steans    Male     Admin Offices              Accountant I
# 3    4        Howard    Male     Admin Offices  Administrative Assistant
# 4    5         Singh    Male     Admin Offices  Administrative Assistant
# 5    6         Smith    Male     Admin Offices  Administrative Assistant
# 6    7       LeBlanc    Male     Admin Offices   Shared Services Manager
# 7    8         Quinn  Female     Admin Offices   Shared Services Manager
# 8    9      Boutwell  Female     Admin Offices            Sr. Accountant
# 9   10  Foster-Baker  Female     Admin Offices            Sr. Accountant
# 10  11          King  Female  Executive Office           President & CEO
# 11  12        Zamora  Female             IT/IS                       CIO
# 12  13        Becker  Female             IT/IS    Database Administrator
# 13  14         Goble  Female             IT/IS    Database Administrator
# 14  15     Hernandez    Male             IT/IS    Database Administrator
# 15  16        Horton    Male             IT/IS    Database Administrator
# 16  17       Johnson    Male             IT/IS    Database Administrator
# 17  18        Murray    Male             IT/IS    Database Administrator
# 18  19       Pearson    Male             IT/IS    Database Administrator
# 19  20     Petrowsky    Male             IT/IS    Database Administrator
# 20  21          Roby    Male             IT/IS    Database Administrator
# 21  22        Rogers    Male             IT/IS    Database Administrator
# 22  23        Salter  Female             IT/IS    Database Administrator
# 23  24        Simard  Female             IT/IS    Database Administrator
# 24  25          Zhou  Female             IT/IS    Database Administrator
# 25  26          Foss  Female             IT/IS               IT Director
# 26  27          Roup  Female             IT/IS           IT Manager - DB
# 27  28          Ruiz  Female             IT/IS           IT Manager - DB
# 28  29        Monroe  Female             IT/IS        IT Manager - Infra
# 29  30       Dougall  Female             IT/IS      IT Manager - Support
# 30  31       Clayton  Female             IT/IS                IT Support
# 31  32         Galia  Female             IT/IS                IT Support
# 32  33       Lindsay  Female             IT/IS                IT Support
# 33  34          Soto  Female             IT/IS                IT Support
# 34  35         Bacon  Female             IT/IS          Network Engineer
# 35  36         Cisco  Female             IT/IS          Network Engineer
# 36  37         Dolan  Female             IT/IS          Network Engineer
# 37  38      Gonzalez  Female             IT/IS          Network Engineer
# 38  39        Merlos    Male             IT/IS          Network Engineer
# 39  40        Morway    Male             IT/IS          Network Engineer
# 40  41       Shepard    Male             IT/IS          Network Engineer
# 41  42    Tredinnick    Male             IT/IS          Network Engineer
# 42  43        Turpin    Male             IT/IS          Network Engineer
# 43  44      Ait Sidi    Male             IT/IS                   Sr. DBA
# 44  45          Carr    Male             IT/IS                   Sr. DBA
# 45  46         Favis  Female             IT/IS                   Sr. DBA
# 46  47      Roehrich  Female             IT/IS                   Sr. DBA
# 47  48       Daniele  Female             IT/IS      Sr. Network Engineer
# 48  49       Lajiri     Male             IT/IS      Sr. Network Engineer
# 49  50    Semizoglou    Male             IT/IS      Sr. Network Engineer
#
#     Years_Exp   Location  Salary
# 0           7  Bangalore   10000
# 1           8  Bangalore   10000
# 2           7  Bangalore   10000
# 3           4  Bangalore   15000
# 4           9  Bangalore   15000
# 5           3  Bangalore   15000
# 6           2  Bangalore   20000
# 7           4  Bangalore   20000
# 8           5  Bangalore   20000
# 9           3  Bangalore   20000
# 10          4  Bangalore  120000
# 11          6  Bangalore  120000
# 12          4  Bangalore   50000
# 13          5  Bangalore   50000
# 14          3  Bangalore   50000
# 15          6  Bangalore   50000
# 16          2  Bangalore   50000
# 17          3  Bangalore   50000
# 18          4  Bangalore   50000
# 19          5  Bangalore   50000
# 20          4  Bangalore   50000
# 21          6  Bangalore   50000
# 22          5  Bangalore   50000
# 23          7  Bangalore   50000
# 24          8  Bangalore   50000
# 25          7  Bangalore   75000
# 26          5  Bangalore   75000
# 27          4  Bangalore   75000
# 28          5  Bangalore   75000
# 29          5  Bangalore   75000
# 30          5  Bangalore   80000
# 31          5  Bangalore   80000
# 32          5  Bangalore   80000
# 33          9  Bangalore   80000
# 34          8  Bangalore   85000
# 35          6  Bangalore   85000
# 36          5  Bangalore   85000
# 37          6  Bangalore   85000
# 38          4  Bangalore   85000
# 39          4  Bangalore   85000
# 40          5  Bangalore   85000
# 41          6  Bangalore   85000
# 42          6  Bangalore   85000
# 43          3  Bangalore   95000
# 44          6  Bangalore   95000
# 45          7  Bangalore   95000
# 46          5  Bangalore   95000
# 47          6  Bangalore  100000
# 48          4  Bangalore  100000
# 49          4  Bangalore  100000

# %% [markdown]
# -----------------

# %% [markdown]
# **Q.no(6). Write a code to replace all the `1` in the `year of experience` to `2` of `data_02`and assign it to the new dataframe named as `data_03`.**

# %%
data_03 = data_02.copy()
data_03['Years_Exp'].replace(to_replace=1 , value=2,inplace=True)
data_03
# Out:
#     Id        F_Name     Sex        Department               Designation  \
# 0    1         Brown    Male     Admin Offices              Accountant I
# 1    2     LaRotonda    Male     Admin Offices              Accountant I
# 2    3        Steans    Male     Admin Offices              Accountant I
# 3    4        Howard    Male     Admin Offices  Administrative Assistant
# 4    5         Singh    Male     Admin Offices  Administrative Assistant
# 5    6         Smith    Male     Admin Offices  Administrative Assistant
# 6    7       LeBlanc    Male     Admin Offices   Shared Services Manager
# 7    8         Quinn  Female     Admin Offices   Shared Services Manager
# 8    9      Boutwell  Female     Admin Offices            Sr. Accountant
# 9   10  Foster-Baker  Female     Admin Offices            Sr. Accountant
# 10  11          King  Female  Executive Office           President & CEO
# 11  12        Zamora  Female             IT/IS                       CIO
# 12  13        Becker  Female             IT/IS    Database Administrator
# 13  14         Goble  Female             IT/IS    Database Administrator
# 14  15     Hernandez    Male             IT/IS    Database Administrator
# 15  16        Horton    Male             IT/IS    Database Administrator
# 16  17       Johnson    Male             IT/IS    Database Administrator
# 17  18        Murray    Male             IT/IS    Database Administrator
# 18  19       Pearson    Male             IT/IS    Database Administrator
# 19  20     Petrowsky    Male             IT/IS    Database Administrator
# 20  21          Roby    Male             IT/IS    Database Administrator
# 21  22        Rogers    Male             IT/IS    Database Administrator
# 22  23        Salter  Female             IT/IS    Database Administrator
# 23  24        Simard  Female             IT/IS    Database Administrator
# 24  25          Zhou  Female             IT/IS    Database Administrator
# 25  26          Foss  Female             IT/IS               IT Director
# 26  27          Roup  Female             IT/IS           IT Manager - DB
# 27  28          Ruiz  Female             IT/IS           IT Manager - DB
# 28  29        Monroe  Female             IT/IS        IT Manager - Infra
# 29  30       Dougall  Female             IT/IS      IT Manager - Support
# 30  31       Clayton  Female             IT/IS                IT Support
# 31  32         Galia  Female             IT/IS                IT Support
# 32  33       Lindsay  Female             IT/IS                IT Support
# 33  34          Soto  Female             IT/IS                IT Support
# 34  35         Bacon  Female             IT/IS          Network Engineer
# 35  36         Cisco  Female             IT/IS          Network Engineer
# 36  37         Dolan  Female             IT/IS          Network Engineer
# 37  38      Gonzalez  Female             IT/IS          Network Engineer
# 38  39        Merlos    Male             IT/IS          Network Engineer
# 39  40        Morway    Male             IT/IS          Network Engineer
# 40  41       Shepard    Male             IT/IS          Network Engineer
# 41  42    Tredinnick    Male             IT/IS          Network Engineer
# 42  43        Turpin    Male             IT/IS          Network Engineer
# 43  44      Ait Sidi    Male             IT/IS                   Sr. DBA
# 44  45          Carr    Male             IT/IS                   Sr. DBA
# 45  46         Favis  Female             IT/IS                   Sr. DBA
# 46  47      Roehrich  Female             IT/IS                   Sr. DBA
# 47  48       Daniele  Female             IT/IS      Sr. Network Engineer
# 48  49       Lajiri     Male             IT/IS      Sr. Network Engineer
# 49  50    Semizoglou    Male             IT/IS      Sr. Network Engineer
#
#     Years_Exp   Location  Salary
# 0           7  Bangalore   10000
# 1           8  Bangalore   10000
# 2           7  Bangalore   10000
# 3           4  Bangalore   15000
# 4           9  Bangalore   15000
# 5           3  Bangalore   15000
# 6           2  Bangalore   20000
# 7           4  Bangalore   20000
# 8           5  Bangalore   20000
# 9           3  Bangalore   20000
# 10          4  Bangalore  120000
# 11          6  Bangalore  120000
# 12          4  Bangalore   50000
# 13          5  Bangalore   50000
# 14          3  Bangalore   50000
# 15          6  Bangalore   50000
# 16          2  Bangalore   50000
# 17          3  Bangalore   50000
# 18          4  Bangalore   50000
# 19          5  Bangalore   50000
# 20          4  Bangalore   50000
# 21          6  Bangalore   50000
# 22          5  Bangalore   50000
# 23          7  Bangalore   50000
# 24          8  Bangalore   50000
# 25          7  Bangalore   75000
# 26          5  Bangalore   75000
# 27          4  Bangalore   75000
# 28          5  Bangalore   75000
# 29          5  Bangalore   75000
# 30          5  Bangalore   80000
# 31          5  Bangalore   80000
# 32          5  Bangalore   80000
# 33          9  Bangalore   80000
# 34          8  Bangalore   85000
# 35          6  Bangalore   85000
# 36          5  Bangalore   85000
# 37          6  Bangalore   85000
# 38          4  Bangalore   85000
# 39          4  Bangalore   85000
# 40          5  Bangalore   85000
# 41          6  Bangalore   85000
# 42          6  Bangalore   85000
# 43          3  Bangalore   95000
# 44          6  Bangalore   95000
# 45          7  Bangalore   95000
# 46          5  Bangalore   95000
# 47          6  Bangalore  100000
# 48          4  Bangalore  100000
# 49          4  Bangalore  100000

# %% [markdown]
# -----------------

# %% [markdown]
# **Q.no(7). Write a code to identify duplicates in `Designation` column and show a `count` of it from `data_02`.**

# %%
data_02[data_02['Designation'].duplicated()]['Designation'].count()
# Out:
# 35

# %% [markdown]
# --------------

# %% [markdown]
# **Q.no(8). Write a code to show `average` `salary` of all the employees.**

# %%
data_02.Salary.mean()
# Out:
# 63700.0

# %% [markdown]
# ---------------

# %% [markdown]
# **Q.no(9). Write a code to show mostly `designated position` for all the employees from employees dataset.**

# %%
data_02.pivot_table(index='Designation',aggfunc='count')['Id'].idxmax()
# Out:
# 'Database Administrator'

# %% [markdown]
# ----------------

# %% [markdown]
# **Q.no(10). Write a code to show the `average salary` for all `individual` `'designations'`.**

# %%
data_02.groupby('Designation')['Salary'].mean()
# Out:
# Designation
# Accountant I                 10000
# Administrative Assistant     15000
# CIO                         120000
# Database Administrator       50000
# IT Director                  75000
# IT Manager - DB              75000
# IT Manager - Infra           75000
# IT Manager - Support         75000
# IT Support                   80000
# Network Engineer             85000
# President & CEO             120000
# Shared Services Manager      20000
# Sr. Accountant               20000
# Sr. DBA                      95000
# Sr. Network Engineer        100000
# Name: Salary, dtype: int64

# %% [markdown]
# -----------------

# %% [markdown]
# **Q.no(11). Write a code to show how much do the `salary` is `skewed` in `employees dataset`.**

# %%
data_02['Salary'].skew()
# Out:
# -0.32966939158331143

# %% [markdown]
# -------------------------

# %% [markdown]
# **Q.no(12). Write a code to show how much is the `kurtosis` in `salary` column for employees dataset.**

# %%
data_02['Salary'].kurt()
# Out:
# -0.8674403189534878

# %% [markdown]
# # --------------------------------------- HAPPY LEARNING --------------------------------------------

# %% [markdown]
# --------------------
