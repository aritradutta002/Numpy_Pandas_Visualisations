# %%
# Pivot table, Merge, Melt, rename, replace, duplicates, apply: Utility Functions in Pandas

# %%
import pandas as pd

# %%
#ITP->Guru material-> vinay Sir-> 8th_June_files-2.zip
# 2 files: train.csv and test.csv

# %%
data1= pd.read_csv('train.csv')
data2 = pd.read_csv('test.csv')

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data2.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
#1 Write a code to concatenate data1 & data2 assign it as data_01

# %%
data01=pd.concat(objs=[data1,data2],axis=0,join='inner',sort=False)

# %%
data01
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 413         1305       3                                 Spector, Mr. Woolf
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
# 415         1307       3                       Saether, Mr. Simon Sivertsen
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
#groupby

# %%
# agg func: max, mean, median, 
# 1. calculate: for 1 column
# 2. groupby
# 3. pivot_table

#more than 1 column: either 2, 3

# %%
#2. Write a code to show the average fare for all individual 'Pclass' for data_01

# %%
#fare, mean, pclass

# %%
avg = data01.groupby(by = 'Pclass')['Fare'].mean()
avg
# Out:
# Pclass
# 1    87.508992
# 2    21.179196
# 3    13.302889
# Name: Fare, dtype: float64

# %%
data01[data01['Pclass']==2].mean()['Fare']
# Out:
# 21.1791963898917

# %%
# 3. average pclass for all the individual embarked positions

# %%
avge = data01.groupby(by = 'Embarked')['Pclass'].mean()
avge
# Out:
# Embarked
# C    1.851852
# Q    2.894309
# S    2.347921
# Name: Pclass, dtype: float64

# %%
#3. Write a code to show the median for 'Age' and mean for 'Fare' on the basis of Sex.

# %%
#hint: use agg({columnname:func,c2:f2})

# %%
import numpy as np
data01.groupby(by='Sex').agg({'Age':np.median,'Fare':np.mean})
# Out:
#          Age       Fare
# Sex
# female  27.0  46.198097
# male    28.0  26.154601

# %%
q3 = data01.groupby(by = 'Sex')[['Age','Fare']].agg([np.median,np.mean])
q3
# Out:
#           Age                Fare
#        median       mean   median       mean
# Sex
# female   27.0  28.687088  23.0000  46.198097
# male     28.0  30.585228  11.8875  26.154601

# %%
avg = data01.groupby(by='Sex')[['Age','Fare']].agg(['median','mean'])
avg
# Out:
#           Age                Fare
#        median       mean   median       mean
# Sex
# female   27.0  28.687088  23.0000  46.198097
# male     28.0  30.585228  11.8875  26.154601

# %%
#Pivot Table

# %%
#4. Write a code to show the average age of all the genders as per there respective passenger class(Pclass) for data_01.

# %%
gender_avg=data1.groupby(by=['Pclass','Sex'])['Age'].mean()
gender_avg
# Out:
# Pclass  Sex
# 1       female    34.611765
#         male      41.281386
# 2       female    28.722973
#         male      30.740707
# 3       female    21.750000
#         male      26.507589
# Name: Age, dtype: float64

# %%
data01.pivot_table(index= 'Sex',columns = 'Pclass',values = 'Age',aggfunc='mean')
# Out:
# Pclass          1          2          3
# Sex
# female  37.037594  27.499223  22.185329
# male    41.029272  30.815380  25.962264

# %%
data01.pivot_table(index= 'Pclass',columns = 'Sex',values = 'Age',aggfunc='mean')
# Out:
# Sex        female       male
# Pclass
# 1       37.037594  41.029272
# 2       27.499223  30.815380
# 3       22.185329  25.962264

# %%
#5. Write a code to show the median age of all the genders and average Fare as per there respective passenger class(Pclass) for data_01.

# %%
import numpy as np
data01.groupby(by='Sex').agg({'Age':np.median,'Fare':np.mean})
# Out:
#          Age       Fare
# Sex
# female  27.0  46.198097
# male    28.0  26.154601

# %%
data01.pivot_table(index = 'Sex' ,columns= 'Pclass',values = ['Age','Fare'],aggfunc= ['median','mean'])
# Out:
#        median                                            mean             \
#           Age                  Fare                       Age
# Pclass      1     2     3         1     2        3          1          2
# Sex
# female   36.0  28.0  22.0  80.92915  23.0  10.4896  37.037594  27.499223
# male     42.0  29.5  25.0  49.50420  13.0   7.8958  41.029272  30.815380
#
#
#                          Fare
# Pclass          3           1          2          3
# Sex
# female  22.185329  109.412385  23.234827  15.324250
# male    25.962264   69.888385  19.904946  12.415462

# %%
pd.pivot_table(data01,aggfunc={'Age':np.median,'Fare':np.mean},columns='Sex',index='Pclass')
# Out:
#           Age              Fare
# Sex    female  male      female       male
# Pclass
# 1        36.0  42.0  109.412385  69.888385
# 2        28.0  29.5   23.234827  19.904946
# 3        22.0  25.0   15.324250  12.415462

# %%
data01.pivot_table(aggfunc={'Age':np.median,'Fare':np.mean},columns='Sex',index='Pclass')
# Out:
#           Age              Fare
# Sex    female  male      female       male
# Pclass
# 1        36.0  42.0  109.412385  69.888385
# 2        28.0  29.5   23.234827  19.904946
# 3        22.0  25.0   15.324250  12.415462

# %%
#Make 2 new columns First_Name and Last_Name by splitting the Name column

# %%
#apply, map
#split

# %%
'Khan,Shahrukh'.split(',')
# Out:
# ['Khan', 'Shahrukh']

# %%
fn= lambda s: s.split(',')[1] 
ln = lambda s: s.split(',')[0]

# %%
data01['First_name']=data01['Name'].apply(fn)
data01['Last_name']=data01['Name'].apply(ln)
data01
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 413         1305       3                                 Spector, Mr. Woolf
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
# 415         1307       3                       Saether, Mr. Simon Sivertsen
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
data01['Ln']=data01['Name'].map(ln)
data01
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 413         1305       3                                 Spector, Mr. Woolf
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
# 415         1307       3                       Saether, Mr. Simon Sivertsen
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
matrix = [(222, 16, 23),
          (333, 31, 11),
          (444, 34, 11),
          ]
 
# Create a DataFrame object of 3X3 Matrix
dfObj = pd.DataFrame(matrix, index=list('abc'))

# %%
mult = lambda x :x*10

# %%
dfObj.apply(mult)
# Out:
#       0    1    2
# a  2220  160  230
# b  3330  310  110
# c  4440  340  110

# %%
dfObj
# Out:
#      0   1   2
# a  222  16  23
# b  333  31  11
# c  444  34  11

# %%
dfObj.map(mult)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-15ad2a949bf8> in <module>
# ----> 1 dfObj.map(mult)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'map'

# %%
# Write a code to RENAME the column from sex to gender and assign it to the new dataframe named as data_02

# %%
data02 = data01.rename({'Sex':'gender'},axis = 1)

# %%
data02
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 413         1305       3                                 Spector, Mr. Woolf
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
# 415         1307       3                       Saether, Mr. Simon Sivertsen
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
chipo=pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep='\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
chipo.groupby('order_id').sum()
# Out:
#           quantity
# order_id
# 1                4
# 2                2
# 3                2
# 4                2
# 5                2
# ...            ...
# 1830             2
# 1831             3
# 1832             2
# 1833             2
# 1834             3
#
# [1834 rows x 1 columns]

# %%
chipo.groupby('item_name').count().sort_values('quantity').tail(1).index[0]
# Out:
# 'Chicken Bowl'

# %%
asd=chipo.groupby(by='order_id').sum()   
asd.sort_values(by='quantity',ascending=False)
# Out:
#           quantity
# order_id
# 1443            35
# 926             23
# 1786            20
# 1660            19
# 759             18
# ...            ...
# 819              1
# 821              1
# 107              1
# 1311             1
# 72               1
#
# [1834 rows x 1 columns]

# %%
chipo[chipo['item_name']=='Bottled Water'].count()
# Out:
# order_id              162
# quantity              162
# item_name             162
# choice_description      0
# item_price            162
# dtype: int64

# %%
asd
# Out:
#           quantity
# order_id
# 1                4
# 2                2
# 3                2
# 4                2
# 5                2
# ...            ...
# 1830             2
# 1831             3
# 1832             2
# 1833             2
# 1834             3
#
# [1834 rows x 1 columns]
